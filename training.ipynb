# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn

# %%
import os
import cv2
import numpy as np
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic
#
# Initialize MediaPipe Holistic model and drawing utilities

# %%
# 'mp_holistic' provides the holistic model which includes face, pose, and hand landmarks detection.
mp_holistic = mp.solutions.holistic

# 'mp_drawing' provides utility functions for drawing the detected landmarks on images.
mp_drawing = mp.solutions.drawing_utils

# %%
# Function to perform MediaPipe detection on an image
def mediapipe_detection(image, model):
    # Convert the image from BGR to RGB color space.
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Mark the image as not writable to improve performance by preventing unnecessary data copying.
    image.flags.writeable = False 
    
    # Process the image using the provided model to detect landmarks.
    results = model.process(image)
    
    # Mark the image as writable again for further operations.
    image.flags.writeable = True
    
    # Convert the image back from RGB to BGR color space.
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    # Return the processed image and the detection results.
    return image, results

# %%
# Function to draw landmarks on an image based on the detection results
def draw_landmarks(image, results):
    # If face landmarks are detected, draw them on the image.
    if results.face_landmarks:
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS)
    
    # If pose landmarks are detected, draw them on the image.
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    
    # If left hand landmarks are detected, draw them on the image.
    if results.left_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    
    # If right hand landmarks are detected, draw them on the image.
    if results.right_hand_landmarks:
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
# Function to extract keypoint values from the MediaPipe detection results
def extract_keypoints(results):
    # Extract pose landmarks (if available) and flatten the list.
    # Each landmark includes x, y, z coordinates and visibility.
    # If pose landmarks are not available, return an array of zeros with the same length.
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    
    # Extract face landmarks (if available) and flatten the list.
    # Each landmark includes x, y, z coordinates.
    # If face landmarks are not available, return an array of zeros with the same length.
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    
    # Extract left hand landmarks (if available) and flatten the list.
    # Each landmark includes x, y, z coordinates.
    # If left hand landmarks are not available, return an array of zeros with the same length.
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    
    # Extract right hand landmarks (if available) and flatten the list.
    # Each landmark includes x, y, z coordinates.
    # If right hand landmarks are not available, return an array of zeros with the same length.
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    # Concatenate all the extracted keypoints (pose, face, left hand, right hand) into a single array.
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Define the base directory where data will be stored
COLLECTIONS_PATH = os.path.join('collections') 

# Define the list of actions to be collected (e.g., 'one', 'two', 'three')
actions = np.array(['one', 'two', 'three'])

# Define the number of sequences to be collected for each action
no_sequences = 30

# Define the length of each sequence (number of frames per sequence)
sequence_length = 30

# Define the starting folder index
start_folder = 1

# %%
# Loop through each action to create necessary directories
for action in actions:
    # Create the path for the current action
    action_path = os.path.join(COLLECTIONS_PATH, action)
    
    # If the directory for the current action does not exist, create it
    if not os.path.exists(action_path):
        os.makedirs(action_path)
    
    # List all existing directories in the action path
    existing_dirs = np.array(os.listdir(action_path))
    
    # Find the highest existing directory number to continue numbering sequences sequentially
    dirmax = np.max(existing_dirs.astype(int)) if len(existing_dirs) > 0 else 0
    
    # Loop through the number of sequences to be created
    for sequence in range(1, no_sequences + 1):
        try:
            # Create a new directory for each sequence
            os.makedirs(os.path.join(COLLECTIONS_PATH, action, str(dirmax + sequence)))
        except:
            # Pass if there's any exception (e.g., directory already exists)
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
# Initialize video capture from the webcam (device index 1)
cap = cv2.VideoCapture(1)

# Use MediaPipe's holistic model for detection and tracking with specified confidence levels
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    # Loop through each action to be collected
    for action in actions:
        # Loop through each sequence to be collected for the current action
        cv2.waitKey(1500)  # Wait for 1500 milliseconds (1.5 seconds)
        for sequence in range(start_folder, start_folder + no_sequences):
            # Loop through each frame in the sequence
            for frame_num in range(sequence_length):
                
                # Read a frame from the webcam
                ret, frame = cap.read()
                
                # Perform MediaPipe detection on the frame
                image, results = mediapipe_detection(frame, holistic)
                
                # Draw landmarks on the detected frame
                draw_landmarks(image, results)
                
                # If it's the first frame of the sequence, display a starting message
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    # Show the frame with the starting message
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)  # Wait for 500 milliseconds (0.5 seconds)
                else:
                    # Display collection progress on subsequent frames
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    # Show the frame with the collection progress
                    cv2.imshow('OpenCV Feed', image)
                
                # Extract keypoints from the detection results
                keypoints = extract_keypoints(results)
                
                # Create a path for saving the keypoints as a numpy file
                npy_path = os.path.join(COLLECTIONS_PATH, action, str(sequence), str(frame_num))
                
                # Save the keypoints to the specified path
                np.save(npy_path, keypoints)
                
                # Break the loop if 'q' key is pressed
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    # Release the video capture object and close all OpenCV windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717009830.276748 1679283 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1717009830.355686 1679629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.361288 1679629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.362503 1679629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.362503 1679631 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.363124 1679626 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.365714 1679626 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.367596 1679631 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1717009830.368353 1679629 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Users/hello_world/workspace_school/ML/test/.venv/lib/python3.12/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
cv2.waitKey(1)
cv2.waitKey(1)
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
# Import necessary libraries for data preprocessing and model training
from sklearn.model_selection import train_test_split
import keras
from keras.utils import to_categorical

# Create a dictionary to map each action label to a unique numeric identifier
label_map = {label: num for num, label in enumerate(actions)}

# Initialize lists to hold sequences and their corresponding labels
sequences, labels = [], []

# %%
# Loop through each action to process its sequences
for action in actions:
    # Loop through each sequence for the current action
    for sequence in np.array(os.listdir(os.path.join(COLLECTIONS_PATH, action))).astype(int):
        window = []  # Initialize a list to hold frames for the current sequence
        # Loop through each frame in the sequence
        for frame_num in range(sequence_length):
            file_path = os.path.join(COLLECTIONS_PATH, action, str(sequence), "{}.npy".format(frame_num))  # Construct the file path
            if os.path.isfile(file_path):  # Check if the file exists
                res = np.load(file_path)  # Load the keypoint data from the file
                window.append(res)  # Append the keypoint data to the current sequence
            else:
                print('File not found: ', file_path)  # Print a message if the file is not found
        sequences.append(window)  # Append the completed sequence to the sequences list
        labels.append(label_map[action])  # Append the corresponding label to the labels list

# %%
# Convert the list of sequences to a NumPy array
X = np.array(sequences)

# %%
# Convert labels to categorical format (one-hot encoding)
y = to_categorical(labels).astype(int)

# %%
# Split the data into training and testing sets (95% training, 5% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
# Import necessary libraries for building and training the neural network
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import TensorBoard

# Define the directory where TensorBoard logs will be saved
log_dir = os.path.join('Logs')
# Initialize the TensorBoard callback
tb_callback = TensorBoard(log_dir=log_dir)

# Initialize a sequential model
model = Sequential()

# Add the first LSTM layer with 64 units, return sequences, and ReLU activation
# The input shape is (30, 1662), where 30 is the sequence length and 1662 is the number of features (keypoints)
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))

# Add a second LSTM layer with 128 units, return sequences, and ReLU activation
model.add(LSTM(128, return_sequences=True, activation='relu'))

# Add a third LSTM layer with 64 units, without returning sequences, and ReLU activation
model.add(LSTM(64, return_sequences=False, activation='relu'))

# Add a dense (fully connected) layer with 64 units and ReLU activation
model.add(Dense(64, activation='relu'))

# Add another dense layer with 32 units and ReLU activation
model.add(Dense(32, activation='relu'))

# Add the output layer with a number of units equal to the number of actions, and softmax activation
# Softmax activation is used for multi-class classification
model.add(Dense(actions.shape[0], activation='softmax'))

# Compile the model with the Adam optimizer, categorical crossentropy loss, and categorical accuracy metric
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# /Users/hello_world/workspace_school/ML/test/.venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model with the training data
# Set the number of epochs to 2000 and use the TensorBoard callback for logging
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - categorical_accuracy: 0.2420 - loss: 1.4489
# Epoch 2/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.2229 - loss: 3.6525
# Epoch 3/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - categorical_accuracy: 0.1884 - loss: 1.3507
# Epoch 4/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.3413 - loss: 1.3198
# Epoch 5/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.4101 - loss: 1.2246
# Epoch 6/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.4784 - loss: 1.0669
# Epoch 7/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.4166 - loss: 1.1091
# Epoch 8/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.4601 - loss: 1.0391
# Epoch 9/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.5387 - loss: 0.9224
# Epoch 10/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.4393 - loss: 1.0301
# Epoch 11/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.4976 - loss: 0.9264
# Epoch 12/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.3072 - loss: 1.3625
# Epoch 13/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.4377 - loss: 1.0938
# Epoch 14/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.4537 - loss: 1.3723
# Epoch 15/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.5973 - loss: 0.9879
# Epoch 16/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.4757 - loss: 1.0198
# Epoch 17/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.5171 - loss: 0.9226
# Epoch 18/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.6188 - loss: 0.8468
# Epoch 19/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - categorical_accuracy: 0.5725 - loss: 0.8295
# Epoch 20/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - categorical_accuracy: 0.6031 - loss: 0.7372
# Epoch 21/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.5834 - loss: 0.8605
# Epoch 22/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.5397 - loss: 0.9946
# Epoch 23/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.5992 - loss: 0.8509
# Epoch 24/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6018 - loss: 0.7614
# Epoch 25/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4978 - loss: 1.9413
# Epoch 26/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.5118 - loss: 0.9666
# Epoch 27/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - categorical_accuracy: 0.4868 - loss: 1.4287
# Epoch 28/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.3431 - loss: 2.4369
# Epoch 29/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.4958 - loss: 1.0663
# Epoch 30/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.3792 - loss: 1.1352
# Epoch 31/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.5926 - loss: 0.9333
# Epoch 32/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.5639 - loss: 0.8401
# Epoch 33/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.5697 - loss: 0.8466
# Epoch 34/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.6956 - loss: 0.7116
# Epoch 35/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 0.5437 - loss: 0.8099
# Epoch 36/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.5879 - loss: 0.7923
# Epoch 37/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6831 - loss: 0.7049
# Epoch 38/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.6685 - loss: 0.7465
# Epoch 39/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5578 - loss: 0.7601
# Epoch 40/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.6052 - loss: 0.7599
# Epoch 41/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.5387 - loss: 0.7825
# Epoch 42/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.6392 - loss: 0.7455
# Epoch 43/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6784 - loss: 0.6565
# Epoch 44/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.6446 - loss: 0.7491
# Epoch 45/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6133 - loss: 0.7447
# Epoch 46/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5321 - loss: 0.8211
# Epoch 47/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.6123 - loss: 0.7440
# Epoch 48/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6217 - loss: 0.8546
# Epoch 49/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7018 - loss: 0.7122
# Epoch 50/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.7156 - loss: 0.6147
# Epoch 51/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.6900 - loss: 0.6762
# Epoch 52/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5924 - loss: 0.7351
# Epoch 53/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6900 - loss: 0.6650
# Epoch 54/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6859 - loss: 0.6138
# Epoch 55/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7559 - loss: 0.5859
# Epoch 56/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.7286 - loss: 0.5495
# Epoch 57/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8300 - loss: 0.5818
# Epoch 58/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6908 - loss: 0.6132
# Epoch 59/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7544 - loss: 1.0428
# Epoch 60/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7964 - loss: 0.4897
# Epoch 61/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7736 - loss: 0.4750
# Epoch 62/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8475 - loss: 0.4788
# Epoch 63/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6952 - loss: 0.6652
# Epoch 64/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7076 - loss: 0.5797
# Epoch 65/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7688 - loss: 0.5135
# Epoch 66/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7933 - loss: 0.4999
# Epoch 67/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8654 - loss: 0.3633
# Epoch 68/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8804 - loss: 0.3453
# Epoch 69/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.8817 - loss: 0.3379
# Epoch 70/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9015 - loss: 0.2954
# Epoch 71/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6178 - loss: 1.2208
# Epoch 72/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.5015 - loss: 1.2911
# Epoch 73/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5992 - loss: 0.8330
# Epoch 74/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6573 - loss: 0.7445
# Epoch 75/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7684 - loss: 0.6619
# Epoch 76/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8335 - loss: 0.6502
# Epoch 77/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.7605 - loss: 0.6489
# Epoch 78/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8159 - loss: 0.6504
# Epoch 79/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7758 - loss: 0.5894
# Epoch 80/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8073 - loss: 0.5712
# Epoch 81/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8254 - loss: 0.5209
# Epoch 82/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8526 - loss: 0.5054
# Epoch 83/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7163 - loss: 0.5876
# Epoch 84/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8289 - loss: 0.4454
# Epoch 85/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8303 - loss: 0.4575
# Epoch 86/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8658 - loss: 0.4003
# Epoch 87/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8741 - loss: 0.3691
# Epoch 88/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.7922 - loss: 0.4548
# Epoch 89/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8419 - loss: 0.4114
# Epoch 90/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8020 - loss: 0.4105
# Epoch 91/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.8107 - loss: 0.4617
# Epoch 92/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7389 - loss: 0.4999
# Epoch 93/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.7572 - loss: 0.4869
# Epoch 94/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.7835 - loss: 0.5045
# Epoch 95/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7686 - loss: 0.5322
# Epoch 96/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.7985 - loss: 0.5049
# Epoch 97/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7518 - loss: 0.5205
# Epoch 98/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8660 - loss: 0.3948
# Epoch 99/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8270 - loss: 0.4352
# Epoch 100/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7976 - loss: 0.4840
# Epoch 101/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7884 - loss: 0.4359
# Epoch 102/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7971 - loss: 0.4728
# Epoch 103/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8027 - loss: 0.4650
# Epoch 104/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.8821 - loss: 0.3369
# Epoch 105/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8553 - loss: 0.3464
# Epoch 106/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9100 - loss: 0.3108
# Epoch 107/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9104 - loss: 0.2912
# Epoch 108/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.8870 - loss: 0.3084
# Epoch 109/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.8912 - loss: 0.2570
# Epoch 110/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9487 - loss: 0.2385
# Epoch 111/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9079 - loss: 0.2329
# Epoch 112/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8651 - loss: 0.3095
# Epoch 113/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8843 - loss: 0.2678
# Epoch 114/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9003 - loss: 0.2296
# Epoch 115/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9100 - loss: 0.2852
# Epoch 116/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8332 - loss: 0.3328
# Epoch 117/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8554 - loss: 0.3091
# Epoch 118/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8959 - loss: 0.2895
# Epoch 119/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6713 - loss: 0.8253
# Epoch 120/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8698 - loss: 0.3998
# Epoch 121/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8012 - loss: 0.4825
# Epoch 122/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7598 - loss: 0.5523
# Epoch 123/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8340 - loss: 0.4241
# Epoch 124/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7588 - loss: 0.4596
# Epoch 125/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8940 - loss: 0.3626
# Epoch 126/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9044 - loss: 0.3234
# Epoch 127/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8730 - loss: 0.2939
# Epoch 128/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.8755 - loss: 0.3189
# Epoch 129/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9271 - loss: 0.2670
# Epoch 130/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8118 - loss: 0.3329
# Epoch 131/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.8944 - loss: 0.2385
# Epoch 132/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9135 - loss: 0.2262
# Epoch 133/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9271 - loss: 0.1945
# Epoch 134/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9394 - loss: 0.2020
# Epoch 135/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9124 - loss: 0.2117
# Epoch 136/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8853 - loss: 0.2842
# Epoch 137/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7836 - loss: 0.5710
# Epoch 138/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8689 - loss: 0.2655
# Epoch 139/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9115 - loss: 0.2563
# Epoch 140/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9243 - loss: 0.2322
# Epoch 141/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.7743 - loss: 0.5820
# Epoch 142/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5402 - loss: 2.1297
# Epoch 143/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.5373 - loss: 1.0513
# Epoch 144/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.6209 - loss: 2.6726
# Epoch 145/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.6789 - loss: 1.2530
# Epoch 146/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4978 - loss: 1.2720
# Epoch 147/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.3107 - loss: 1.3127
# Epoch 148/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4507 - loss: 1.2608
# Epoch 149/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5247 - loss: 1.1225
# Epoch 150/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6610 - loss: 0.9149
# Epoch 151/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5441 - loss: 0.8655
# Epoch 152/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6710 - loss: 0.7606
# Epoch 153/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.5785 - loss: 0.7992
# Epoch 154/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7194 - loss: 0.7335
# Epoch 155/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7223 - loss: 0.6995
# Epoch 156/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.6276 - loss: 0.6702
# Epoch 157/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7024 - loss: 0.6469
# Epoch 158/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7192 - loss: 0.6029
# Epoch 159/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.7559 - loss: 0.5782
# Epoch 160/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7563 - loss: 0.5468
# Epoch 161/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7384 - loss: 0.5768
# Epoch 162/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7914 - loss: 0.4758
# Epoch 163/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8747 - loss: 0.4279
# Epoch 164/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8072 - loss: 0.4767
# Epoch 165/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8078 - loss: 0.4451
# Epoch 166/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8133 - loss: 0.4094
# Epoch 167/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8000 - loss: 0.3545
# Epoch 168/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - categorical_accuracy: 0.8441 - loss: 0.3791
# Epoch 169/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.8202 - loss: 0.3646
# Epoch 170/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8035 - loss: 0.4127
# Epoch 171/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9204 - loss: 0.2605
# Epoch 172/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.8794 - loss: 0.3422
# Epoch 173/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8850 - loss: 0.2824
# Epoch 174/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9204 - loss: 0.2534
# Epoch 175/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.8786 - loss: 0.2873
# Epoch 176/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7657 - loss: 0.5899
# Epoch 177/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9033 - loss: 0.3033
# Epoch 178/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8615 - loss: 0.3551
# Epoch 179/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.8238 - loss: 0.3765
# Epoch 180/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8751 - loss: 0.3661
# Epoch 181/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8320 - loss: 0.3569
# Epoch 182/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9337 - loss: 0.2675
# Epoch 183/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9292 - loss: 0.2266
# Epoch 184/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.9135 - loss: 0.2403
# Epoch 185/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.9522 - loss: 0.2085
# Epoch 186/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9170 - loss: 0.2275
# Epoch 187/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8638 - loss: 0.3628
# Epoch 188/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.9118 - loss: 0.2442
# Epoch 189/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9055 - loss: 0.2220
# Epoch 190/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9651 - loss: 0.1504
# Epoch 191/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9484 - loss: 0.1464
# Epoch 192/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9342 - loss: 0.1998
# Epoch 193/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9801 - loss: 0.1158
# Epoch 194/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9525 - loss: 0.1403
# Epoch 195/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - categorical_accuracy: 0.9274 - loss: 0.1930
# Epoch 196/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9558 - loss: 0.1530
# Epoch 197/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9236 - loss: 0.1841
# Epoch 198/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.8287 - loss: 0.4970
# Epoch 199/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.7692 - loss: 0.6611
# Epoch 200/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.7872 - loss: 0.4899
# Epoch 201/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8252 - loss: 0.4161
# Epoch 202/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.6871 - loss: 0.6600
# Epoch 203/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7970 - loss: 0.4872
# Epoch 204/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7926 - loss: 0.4877
# Epoch 205/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.7440 - loss: 0.4724
# Epoch 206/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7468 - loss: 0.4416
# Epoch 207/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.8219 - loss: 0.3886
# Epoch 208/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.8829 - loss: 0.3689
# Epoch 209/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 0.9355 - loss: 0.2767
# Epoch 210/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.9689 - loss: 0.2124
# Epoch 211/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9303 - loss: 0.2191
# Epoch 212/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9456 - loss: 0.1985
# Epoch 213/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9467 - loss: 0.2200
# Epoch 214/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.9288 - loss: 0.1949
# Epoch 215/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9408 - loss: 0.1894
# Epoch 216/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9651 - loss: 0.1714
# Epoch 217/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.9641 - loss: 0.1640
# Epoch 218/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9467 - loss: 0.1743
# Epoch 219/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9797 - loss: 0.1277
# Epoch 220/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9602 - loss: 0.1318
# Epoch 221/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9627 - loss: 0.1349
# Epoch 222/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9641 - loss: 0.1363
# Epoch 223/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - categorical_accuracy: 0.9589 - loss: 0.1463
# Epoch 224/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.9651 - loss: 0.1112
# Epoch 225/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9651 - loss: 0.1233
# Epoch 226/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9578 - loss: 0.1033
# Epoch 227/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9707 - loss: 0.1190
# Epoch 228/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9585 - loss: 0.1252
# Epoch 229/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - categorical_accuracy: 0.9268 - loss: 0.1862
# Epoch 230/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9084 - loss: 0.2152
# Epoch 231/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9710 - loss: 0.1202
# Epoch 232/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.8533 - loss: 0.3572
# Epoch 233/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9504 - loss: 0.1324
# Epoch 234/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.9348 - loss: 0.1311
# Epoch 235/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.9651 - loss: 0.0940
# Epoch 236/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9651 - loss: 0.0949
# Epoch 237/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9770 - loss: 0.0982
# Epoch 238/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9543 - loss: 0.1396
# Epoch 239/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9264 - loss: 0.1600
# Epoch 240/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.9059 - loss: 0.2433
# Epoch 241/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9124 - loss: 0.2056
# Epoch 242/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9389 - loss: 0.1884
# Epoch 243/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.8173 - loss: 0.5491
# Epoch 244/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7589 - loss: 0.7366
# Epoch 245/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.6884 - loss: 1.0099
# Epoch 246/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7532 - loss: 0.9172
# Epoch 247/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7840 - loss: 0.7273
# Epoch 248/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.5407 - loss: 1.0810
# Epoch 249/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.6461 - loss: 0.7805
# Epoch 250/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6812 - loss: 0.7118
# Epoch 251/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.8262 - loss: 0.6225
# Epoch 252/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8052 - loss: 0.5402
# Epoch 253/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.8930 - loss: 0.3341
# Epoch 254/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9138 - loss: 0.2508
# Epoch 255/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.9330 - loss: 0.2712
# Epoch 256/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9696 - loss: 0.2091
# Epoch 257/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.9411 - loss: 0.2123
# Epoch 258/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9463 - loss: 0.1608
# Epoch 259/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9305 - loss: 0.3623
# Epoch 260/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3591 - loss: 3.9200
# Epoch 261/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.4880 - loss: 1.6510
# Epoch 262/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.4567 - loss: 1.9149
# Epoch 263/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.4755 - loss: 1.3573
# Epoch 264/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4978 - loss: 1.2237
# Epoch 265/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4928 - loss: 1.0872
# Epoch 266/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.6038 - loss: 0.9203
# Epoch 267/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.5765 - loss: 0.8845
# Epoch 268/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5158 - loss: 1.2261
# Epoch 269/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.3391 - loss: 1.5590
# Epoch 270/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - categorical_accuracy: 0.2363 - loss: 1.3513
# Epoch 271/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.5724 - loss: 1.0118
# Epoch 272/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4973 - loss: 0.8142
# Epoch 273/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.6112 - loss: 0.7881
# Epoch 274/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.5223 - loss: 0.8235
# Epoch 275/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.5648 - loss: 0.8310
# Epoch 276/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6379 - loss: 0.7479
# Epoch 277/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7043 - loss: 0.7167
# Epoch 278/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.6698 - loss: 0.7058
# Epoch 279/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.7643 - loss: 0.6179
# Epoch 280/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.6147 - loss: 0.7328
# Epoch 281/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.6863 - loss: 0.6108
# Epoch 282/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.7131 - loss: 0.5370
# Epoch 283/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7054 - loss: 0.5170
# Epoch 284/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.7422 - loss: 0.4575
# Epoch 285/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.7788 - loss: 0.4431
# Epoch 286/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7535 - loss: 0.5360
# Epoch 287/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.7968 - loss: 0.4677
# Epoch 288/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8406 - loss: 0.4191
# Epoch 289/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - categorical_accuracy: 0.9251 - loss: 0.3132
# Epoch 290/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8021 - loss: 0.3534
# Epoch 291/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.8389 - loss: 0.4261
# Epoch 292/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8501 - loss: 0.3551
# Epoch 293/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.8815 - loss: 0.3755
# Epoch 294/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.8655 - loss: 0.3349
# Epoch 295/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.9122 - loss: 0.2185
# Epoch 296/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.9515 - loss: 0.1894
# Epoch 297/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.8397 - loss: 0.2968
# Epoch 298/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.7919 - loss: 0.4119
# Epoch 299/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9057 - loss: 0.2365
# Epoch 300/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8068 - loss: 0.6645
# Epoch 301/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.7636 - loss: 0.7082
# Epoch 302/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.7602 - loss: 0.5014
# Epoch 303/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.6806 - loss: 0.6055
# Epoch 304/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - categorical_accuracy: 0.8247 - loss: 0.4984
# Epoch 305/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.8616 - loss: 0.4245
# Epoch 306/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - categorical_accuracy: 0.9595 - loss: 0.2932
# Epoch 307/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9480 - loss: 0.2250
# Epoch 308/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.9448 - loss: 0.1915
# Epoch 309/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9683 - loss: 0.1338
# Epoch 310/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9323 - loss: 0.1948
# Epoch 311/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9143 - loss: 0.1933
# Epoch 312/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.9476 - loss: 0.1607
# Epoch 313/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9720 - loss: 0.1463
# Epoch 314/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.9010 - loss: 0.1769
# Epoch 315/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9965 - loss: 0.0986
# Epoch 316/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9944 - loss: 0.0755
# Epoch 317/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9620 - loss: 0.0692
# Epoch 318/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9815 - loss: 0.0455
# Epoch 319/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.9791 - loss: 0.0468
# Epoch 320/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9606 - loss: 0.1406
# Epoch 321/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.9208 - loss: 0.2935
# Epoch 322/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.8118 - loss: 0.5953
# Epoch 323/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.7290 - loss: 0.8906
# Epoch 324/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.8628 - loss: 0.4127
# Epoch 325/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.6492 - loss: 0.6649
# Epoch 326/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.8135 - loss: 0.4051
# Epoch 327/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.9323 - loss: 0.3402
# Epoch 328/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9451 - loss: 0.2307
# Epoch 329/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.9066 - loss: 0.2332
# Epoch 330/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9271 - loss: 0.2560
# Epoch 331/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.9090 - loss: 0.2025
# Epoch 332/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.8209 - loss: 0.4487
# Epoch 333/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.8856 - loss: 0.2416
# Epoch 334/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9271 - loss: 0.1715
# Epoch 335/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9755 - loss: 0.1821
# Epoch 336/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9620 - loss: 0.1154
# Epoch 337/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.9770 - loss: 0.0887
# Epoch 338/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9763 - loss: 0.0812
# Epoch 339/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9888 - loss: 0.0725
# Epoch 340/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.9909 - loss: 0.0618
# Epoch 341/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.9857 - loss: 0.0592
# Epoch 342/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9944 - loss: 0.0372
# Epoch 343/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 1.0000 - loss: 0.0243
# Epoch 344/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 1.0000 - loss: 0.0251
# Epoch 345/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0263
# Epoch 346/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 1.0000 - loss: 0.0262
# Epoch 347/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 1.0000 - loss: 0.0175
# Epoch 348/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0252
# Epoch 349/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.9850 - loss: 0.0285
# Epoch 350/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0147
# Epoch 351/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0136
# Epoch 352/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0113
# Epoch 353/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0083
# Epoch 354/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 1.0000 - loss: 0.0032
# Epoch 355/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 1.0000 - loss: 0.0044
# Epoch 356/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 1.0000 - loss: 0.0033
# Epoch 357/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.9965 - loss: 0.0203
# Epoch 358/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4530 - loss: 17.3828
# Epoch 359/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3144 - loss: 4.1952
# Epoch 360/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4241 - loss: 1.2962
# Epoch 361/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4594 - loss: 1.2075
# Epoch 362/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3463 - loss: 1.2077
# Epoch 363/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3708 - loss: 1.0912
# Epoch 364/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.4187 - loss: 777.4084
# Epoch 365/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.2143 - loss: 3.0032
# Epoch 366/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3219 - loss: 1.4613
# Epoch 367/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - categorical_accuracy: 0.2360 - loss: 143.9415
# Epoch 368/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.2458 - loss: 369.8489
# Epoch 369/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.2475 - loss: 1.5958
# Epoch 370/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2556 - loss: 1.4942
# Epoch 371/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3054 - loss: 1.3715
# Epoch 372/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3988 - loss: 1.3735
# Epoch 373/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.4106 - loss: 1.3609
# Epoch 374/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.3780 - loss: 1.3458
# Epoch 375/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4269 - loss: 1.3346
# Epoch 376/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3552 - loss: 1.2934
# Epoch 377/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.3491 - loss: 1.3098
# Epoch 378/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4229 - loss: 1.2968
# Epoch 379/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3895 - loss: 1.2997
# Epoch 380/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4104 - loss: 1.2749
# Epoch 381/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.4337 - loss: 1.2459
# Epoch 382/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.3903 - loss: 1.2421
# Epoch 383/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3985 - loss: 1.2118
# Epoch 384/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4100 - loss: 1.2054
# Epoch 385/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.4131 - loss: 1.1731
# Epoch 386/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4368 - loss: 1.1246
# Epoch 387/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4508 - loss: 1.1101
# Epoch 388/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.4112 - loss: 1.1634
# Epoch 389/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.4974 - loss: 1.1107
# Epoch 390/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4217 - loss: 1.1993
# Epoch 391/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4268 - loss: 1.2658
# Epoch 392/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.4271 - loss: 1.2757
# Epoch 393/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4789 - loss: 1.2191
# Epoch 394/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.4779 - loss: 1.2927
# Epoch 395/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.4630 - loss: 1.2333
# Epoch 396/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.4058 - loss: 1.1949
# Epoch 397/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4041 - loss: 1.2132
# Epoch 398/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.3610 - loss: 1.2112
# Epoch 399/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3941 - loss: 1.1667
# Epoch 400/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3972 - loss: 1.1716
# Epoch 401/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4404 - loss: 1.1206
# Epoch 402/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4675 - loss: 1.1066
# Epoch 403/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.4043 - loss: 1.1337
# Epoch 404/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.4534 - loss: 1.0942
# Epoch 405/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4360 - loss: 13.8109
# Epoch 406/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.3061 - loss: 1.3392
# Epoch 407/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.2939 - loss: 1.3906
# Epoch 408/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.2762 - loss: 1.3769
# Epoch 409/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.2575 - loss: 1.3981
# Epoch 410/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.2675 - loss: 1.4020
# Epoch 411/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.2765 - loss: 1.3997
# Epoch 412/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.2838 - loss: 1.3810
# Epoch 413/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3067 - loss: 1.3747
# Epoch 414/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3286 - loss: 1.3753
# Epoch 415/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.2525 - loss: 1.3945
# Epoch 416/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.2484 - loss: 1.3863
# Epoch 417/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.2713 - loss: 1.3715
# Epoch 418/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.2619 - loss: 1.3946
# Epoch 419/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.2900 - loss: 1.3774
# Epoch 420/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.2713 - loss: 1.3787
# Epoch 421/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.2827 - loss: 1.3783
# Epoch 422/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.3098 - loss: 1.3614
# Epoch 423/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3296 - loss: 1.3588
# Epoch 424/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.2817 - loss: 1.3837
# Epoch 425/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.2661 - loss: 1.3779
# Epoch 426/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.2577 - loss: 1.3699
# Epoch 427/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.2998 - loss: 1.3662
# Epoch 428/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.2581 - loss: 1.3877
# Epoch 429/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.2894 - loss: 1.3745
# Epoch 430/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.2592 - loss: 1.3837
# Epoch 431/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.2987 - loss: 1.3686
# Epoch 432/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.2883 - loss: 1.3656
# Epoch 433/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.2823 - loss: 1.4070
# Epoch 434/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.2890 - loss: 1.3843
# Epoch 435/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.2869 - loss: 1.3868
# Epoch 436/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.2827 - loss: 1.3907
# Epoch 437/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.2813 - loss: 1.3843
# Epoch 438/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.2588 - loss: 1.3849
# Epoch 439/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.2685 - loss: 1.3895
# Epoch 440/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.2831 - loss: 1.3878
# Epoch 441/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.2644 - loss: 1.3875
# Epoch 442/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.2758 - loss: 1.3878
# Epoch 443/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.2946 - loss: 1.3841
# Epoch 444/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.2737 - loss: 1.3860
# Epoch 445/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3362 - loss: 1.3809
# Epoch 446/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.2977 - loss: 1.3853
# Epoch 447/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.2550 - loss: 1.3872
# Epoch 448/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.2894 - loss: 1.3855
# Epoch 449/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.2821 - loss: 1.3852
# Epoch 450/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 0.3050 - loss: 1.3832
# Epoch 451/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.2717 - loss: 1.3870
# Epoch 452/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.3008 - loss: 1.3836
# Epoch 453/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.2737 - loss: 1.3857
# Epoch 454/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3012 - loss: 1.3833
# Epoch 455/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.2939 - loss: 1.3849
# Epoch 456/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3012 - loss: 1.3849
# Epoch 457/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3043 - loss: 1.3830
# Epoch 458/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.2377 - loss: 1.3876
# Epoch 459/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3043 - loss: 1.3836
# Epoch 460/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.2752 - loss: 1.3856
# Epoch 461/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3314 - loss: 1.3802
# Epoch 462/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.2950 - loss: 1.3837
# Epoch 463/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3012 - loss: 1.3820
# Epoch 464/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2793 - loss: 1.3843
# Epoch 465/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.2606 - loss: 1.3851
# Epoch 466/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.2835 - loss: 1.3844
# Epoch 467/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.2964 - loss: 1.3832
# Epoch 468/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.2849 - loss: 1.3836
# Epoch 469/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.2818 - loss: 1.3836
# Epoch 470/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3193 - loss: 1.3808
# Epoch 471/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.2912 - loss: 1.3821
# Epoch 472/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.2933 - loss: 1.3819
# Epoch 473/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2953 - loss: 1.3825
# Epoch 474/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3189 - loss: 1.3791
# Epoch 475/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3127 - loss: 1.3796
# Epoch 476/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.3022 - loss: 1.3817
# Epoch 477/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - categorical_accuracy: 0.2689 - loss: 1.3816
# Epoch 478/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.2783 - loss: 1.3824
# Epoch 479/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3127 - loss: 1.3791
# Epoch 480/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2991 - loss: 1.3794
# Epoch 481/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.2845 - loss: 1.3795
# Epoch 482/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2970 - loss: 1.3767
# Epoch 483/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2616 - loss: 1.3797
# Epoch 484/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2950 - loss: 1.3723
# Epoch 485/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.2800 - loss: 1.3756
# Epoch 486/2000
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3225 - loss: 1.2893
# Epoch 1842/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 0.3027 - loss: 1.3185
# Epoch 1843/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3465 - loss: 1.2420
# Epoch 1844/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3111 - loss: 1.3175
# Epoch 1845/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.2986 - loss: 1.2671
# Epoch 1846/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3090 - loss: 1.3073
# Epoch 1847/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.3319 - loss: 1.2769
# Epoch 1848/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3173 - loss: 1.2789
# Epoch 1849/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.2965 - loss: 1.2916
# Epoch 1850/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3257 - loss: 1.3078
# Epoch 1851/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.2902 - loss: 1.3357
# Epoch 1852/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3277 - loss: 1.2707
# Epoch 1853/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - categorical_accuracy: 0.3257 - loss: 1.3005
# Epoch 1854/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.2923 - loss: 1.3032
# Epoch 1855/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3100 - loss: 1.3162
# Epoch 1856/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.3277 - loss: 1.2927
# Epoch 1857/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3361 - loss: 1.2881
# Epoch 1858/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3100 - loss: 1.2824
# Epoch 1859/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.3142 - loss: 1.2847
# Epoch 1860/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3100 - loss: 1.2985
# Epoch 1861/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3111 - loss: 1.3194
# Epoch 1862/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3350 - loss: 1.2955
# Epoch 1863/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3236 - loss: 1.3014
# Epoch 1864/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3069 - loss: 1.2720
# Epoch 1865/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.3704 - loss: 1.2491
# Epoch 1866/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3652 - loss: 1.2845
# Epoch 1867/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.3277 - loss: 1.3048
# Epoch 1868/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3163 - loss: 1.3092
# Epoch 1869/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.3236 - loss: 1.2904
# Epoch 1870/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3090 - loss: 1.2781
# Epoch 1871/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3267 - loss: 1.2914
# Epoch 1872/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3361 - loss: 1.3032
# Epoch 1873/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.3632 - loss: 1.2981
# Epoch 1874/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3257 - loss: 1.2836
# Epoch 1875/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3194 - loss: 1.3263
# Epoch 1876/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3204 - loss: 1.2785
# Epoch 1877/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3434 - loss: 1.2744
# Epoch 1878/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 0.2975 - loss: 1.2942
# Epoch 1879/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.3454 - loss: 1.3124
# Epoch 1880/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3444 - loss: 1.2923
# Epoch 1881/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3392 - loss: 1.2814
# Epoch 1882/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3100 - loss: 1.3105
# Epoch 1883/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.2996 - loss: 1.3227
# Epoch 1884/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3246 - loss: 1.2898
# Epoch 1885/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3236 - loss: 1.2984
# Epoch 1886/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3142 - loss: 1.2708
# Epoch 1887/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.3257 - loss: 1.3006
# Epoch 1888/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3319 - loss: 1.2726
# Epoch 1889/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - categorical_accuracy: 0.2850 - loss: 1.3145
# Epoch 1890/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3194 - loss: 1.2983
# Epoch 1891/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3371 - loss: 1.3076
# Epoch 1892/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.3215 - loss: 1.2979
# Epoch 1893/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3548 - loss: 1.3040
# Epoch 1894/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.3027 - loss: 1.2941
# Epoch 1895/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3298 - loss: 1.2671
# Epoch 1896/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3288 - loss: 1.2773
# Epoch 1897/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.3225 - loss: 1.3194
# Epoch 1898/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.3527 - loss: 1.2930
# Epoch 1899/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3392 - loss: 1.2837
# Epoch 1900/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.2954 - loss: 1.3048
# Epoch 1901/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.2892 - loss: 1.3134
# Epoch 1902/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3298 - loss: 1.3046
# Epoch 1903/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - categorical_accuracy: 0.2954 - loss: 1.3207
# Epoch 1904/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3382 - loss: 1.2896
# Epoch 1905/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.3007 - loss: 1.2996
# Epoch 1906/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.3132 - loss: 1.2973
# Epoch 1907/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.3027 - loss: 1.3115
# Epoch 1908/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3059 - loss: 1.3090
# Epoch 1909/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3319 - loss: 1.2766
# Epoch 1910/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.3121 - loss: 1.3012
# Epoch 1911/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3121 - loss: 1.2658
# Epoch 1912/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.3392 - loss: 1.2916
# Epoch 1913/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.3048 - loss: 1.2960
# Epoch 1914/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 0.3454 - loss: 1.2821
# Epoch 1915/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.3309 - loss: 1.3082
# Epoch 1916/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3486 - loss: 1.2961
# Epoch 1917/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.3809 - loss: 1.2669
# Epoch 1918/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.2892 - loss: 1.2975
# Epoch 1919/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3132 - loss: 1.2866
# Epoch 1920/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.3340 - loss: 1.2785
# Epoch 1921/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3215 - loss: 1.2899
# Epoch 1922/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 0.3017 - loss: 1.3006
# Epoch 1923/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.3038 - loss: 1.3052
# Epoch 1924/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3298 - loss: 1.3135
# Epoch 1925/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - categorical_accuracy: 0.3329 - loss: 1.2736
# Epoch 1926/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.3486 - loss: 1.2908
# Epoch 1927/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 0.3100 - loss: 1.2819
# Epoch 1928/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3059 - loss: 1.2877
# Epoch 1929/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.3423 - loss: 1.2788
# Epoch 1930/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 0.3319 - loss: 1.2667
# Epoch 1931/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.2975 - loss: 1.3227
# Epoch 1932/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3319 - loss: 1.2817
# Epoch 1933/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - categorical_accuracy: 0.3361 - loss: 1.2752
# Epoch 1934/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3413 - loss: 1.3030
# Epoch 1935/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - categorical_accuracy: 0.3121 - loss: 1.3125
# Epoch 1936/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3402 - loss: 1.2557
# Epoch 1937/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - categorical_accuracy: 0.3621 - loss: 1.2921
# Epoch 1938/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3590 - loss: 1.2905
# Epoch 1939/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3444 - loss: 1.2827
# Epoch 1940/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.3246 - loss: 1.3062
# Epoch 1941/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - categorical_accuracy: 0.3475 - loss: 1.2759
# Epoch 1942/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.3090 - loss: 1.2876
# Epoch 1943/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - categorical_accuracy: 0.3309 - loss: 1.2845
# Epoch 1944/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - categorical_accuracy: 0.3059 - loss: 1.3043
# Epoch 1945/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - categorical_accuracy: 0.3423 - loss: 1.2701
# Epoch 1946/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.3371 - loss: 1.2933
# Epoch 1947/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3423 - loss: 1.2963
# Epoch 1948/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.3465 - loss: 1.2950
# Epoch 1949/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - categorical_accuracy: 0.3454 - loss: 1.2923
# Epoch 1950/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.3277 - loss: 1.2875
# Epoch 1951/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.3444 - loss: 1.2898
# Epoch 1952/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.3382 - loss: 1.3004
# Epoch 1953/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - categorical_accuracy: 0.3361 - loss: 1.2971
# Epoch 1954/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.3319 - loss: 1.2858
# Epoch 1955/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.3257 - loss: 1.2792
# Epoch 1956/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 0.3246 - loss: 1.2978
# Epoch 1957/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.2913 - loss: 1.2956
# Epoch 1958/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.3496 - loss: 1.2838
# Epoch 1959/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.3142 - loss: 1.3203
# Epoch 1960/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.2934 - loss: 1.2952
# Epoch 1961/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - categorical_accuracy: 0.3736 - loss: 1.2598
# Epoch 1962/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.3413 - loss: 1.2940
# Epoch 1963/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - categorical_accuracy: 0.3413 - loss: 1.2866
# Epoch 1964/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.3527 - loss: 1.2839
# Epoch 1965/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.3288 - loss: 1.2957
# Epoch 1966/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.3402 - loss: 1.3087
# Epoch 1967/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.3600 - loss: 1.2788
# Epoch 1968/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3288 - loss: 1.2710
# Epoch 1969/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 0.3288 - loss: 1.2909
# Epoch 1970/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - categorical_accuracy: 0.3527 - loss: 1.2922
# Epoch 1971/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - categorical_accuracy: 0.3340 - loss: 1.2990
# Epoch 1972/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.2975 - loss: 1.3161
# Epoch 1973/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.3329 - loss: 1.2695
# Epoch 1974/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.2829 - loss: 1.2980
# Epoch 1975/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.3090 - loss: 1.3134
# Epoch 1976/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.3465 - loss: 1.2710
# Epoch 1977/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.3236 - loss: 1.2547
# Epoch 1978/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.3329 - loss: 1.3082
# Epoch 1979/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3809 - loss: 1.2706
# Epoch 1980/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3215 - loss: 1.3038
# Epoch 1981/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3152 - loss: 1.2976
# Epoch 1982/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.3382 - loss: 1.2702
# Epoch 1983/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3611 - loss: 1.2861
# Epoch 1984/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3236 - loss: 1.2940
# Epoch 1985/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - categorical_accuracy: 0.3434 - loss: 1.2799
# Epoch 1986/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.3538 - loss: 1.2969
# Epoch 1987/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - categorical_accuracy: 0.3371 - loss: 1.2980
# Epoch 1988/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.3204 - loss: 1.2997
# Epoch 1989/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.3121 - loss: 1.2879
# Epoch 1990/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - categorical_accuracy: 0.2809 - loss: 1.2982
# Epoch 1991/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3038 - loss: 1.2874
# Epoch 1992/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.3194 - loss: 1.3084
# Epoch 1993/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.3059 - loss: 1.2996
# Epoch 1994/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.3100 - loss: 1.3123
# Epoch 1995/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.2496 - loss: 1.3261
# Epoch 1996/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - categorical_accuracy: 0.3267 - loss: 1.2855
# Epoch 1997/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.2913 - loss: 1.3027
# Epoch 1998/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - categorical_accuracy: 0.3298 - loss: 1.2901
# Epoch 1999/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.3392 - loss: 1.2917
# Epoch 2000/2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3704 - loss: 1.2756

# %%
# Print the summary of the model architecture
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │       442,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,790,126 (6.83 MB)
#  Trainable params: 596,708 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,418 (4.55 MB)

# %% [markdown]
# # 8. Make Predictions

# %%
# Use the trained model to make predictions on the test data
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step

# %%
# Get the predicted action for the fifth sample in the test data
# np.argmax(res[4]) returns the index of the highest probability in the prediction array for the fifth sample
# actions[np.argmax(res[4])] maps this index to the corresponding action
predicted_action = actions[np.argmax(res[4])]

# Get the true action for the fifth sample in the test data
# np.argmax(y_test[4]) returns the index of the highest value in the one-hot encoded true label for the fifth sample
# actions[np.argmax(y_test[4])] maps this index to the corresponding action
true_action = actions[np.argmax(y_test[4])]

# Print the predicted and true actions for comparison
print(f"Predicted action: {predicted_action}")
print(f"True action: {true_action}")
# Out:
# Predicted action: peace
# True action: peace

# %% [markdown]
# # 9. Save Weights
# Save the trained model's weights and architecture to a file named 'collection.h5'

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
# Import necessary functions for evaluation
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# Use the trained model to make predictions on the test data
yhat = model.predict(X_test)

# Convert the true labels from one-hot encoding to integer labels
ytrue = np.argmax(y_test, axis=1).tolist()

# Convert the predicted labels from one-hot encoding to integer labels
yhat = np.argmax(yhat, axis=1).tolist()

# Compute the multilabel confusion matrix
confusion_matrix = multilabel_confusion_matrix(ytrue, yhat)

# Compute the accuracy score
accuracy = accuracy_score(ytrue, yhat)

# Print the results
print("Confusion Matrix:\n", confusion_matrix)
print("Accuracy Score:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Confusion Matrix:
#  [[[3 0]
#   [3 0]]
#
#  [[1 5]
#   [0 0]]
#
#  [[5 0]
#   [1 0]]
#
#  [[4 0]
#   [1 1]]]
# Accuracy Score: 0.16666666666666666
